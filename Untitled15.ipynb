# %%
# !pip install hexalattice
from hexalattice.hexalattice import *
import matplotlib.pyplot as plt

# Get user input for the number of rows and columns
ny = int(input("Enter the number of rows: "))
nx = int(input("Enter the number of columns: "))

# Create the hexagonal grid
hex_centers, _ = create_hex_grid(nx=nx, ny=ny, do_plot=True)

# Display the plot
plt.show()
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for hexalattice: filename=hexalattice-1.3.0-py3-none-any.whl size=7891 sha256=9a0f9862c5eca818168f71d826697f2bd471d0cfca326d6e90f65f0aec79491b
#   Stored in directory: /root/.cache/pip/wheels/82/c4/f8/27d9cf694a1af922dbc532567ddaa892fbd7af8ec00ca05b10
# Successfully built hexalattice
# ...
# Enter the number of rows: 3
# Enter the number of columns: 4
